# %%
import pandas as pd
from data_processor import DataProcessor

# if you wanna see how this works, look at the "Feature Engineering" notebook
dp = DataProcessor()
original_df = pd.read_csv("../data/train.csv")
df = dp.encode_data(original_df)
df
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  BsmtFinSF1  \
# 0            65.0     8450            7            5       196.0         706
# 1            80.0     9600            6            8         0.0         978
# 2            68.0    11250            7            5       162.0         486
# 3            60.0     9550            7            5         0.0         216
# 4            84.0    14260            8            5       350.0         655
# ...           ...      ...          ...          ...         ...         ...
# 1455         62.0     7917            6            5         0.0           0
# 1456         85.0    13175            6            6       119.0         790
# 1457         66.0     9042            7            9         0.0         275
# 1458         68.0     9717            5            6         0.0          49
# 1459         75.0     9937            5            6         0.0         830
#
# ...

# %%
num_df = dp.numerical_data(original_df)
num_df
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  MasVnrArea  BsmtFinSF1  \
# 0            65.0     8450            7            5       196.0         706
# 1            80.0     9600            6            8         0.0         978
# 2            68.0    11250            7            5       162.0         486
# 3            60.0     9550            7            5         0.0         216
# 4            84.0    14260            8            5       350.0         655
# ...           ...      ...          ...          ...         ...         ...
# 1455         62.0     7917            6            5         0.0           0
# 1456         85.0    13175            6            6       119.0         790
# 1457         66.0     9042            7            9         0.0         275
# 1458         68.0     9717            5            6         0.0          49
# 1459         75.0     9937            5            6         0.0         830
#
# ...

# %%
cat_df = dp.categorical_data(original_df)
cat_df
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2
# ...       ...    ...   ...      ...         ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside
#
#      Neighborhood Condition1 Condition2  ... SaleType SaleCondition  \
# 0         CollgCr       Norm       Norm  ...       WD        Normal
# ...

# %%
ord_df = dp.ordinal_data(original_df)
ord_df
# Out:
#      LandSlope BsmtQual BsmtCond BsmtFinType1 BsmtFinType2 HeatingQC  \
# 0          Gtl       Gd       TA          GLQ          Unf        Ex
# 1          Gtl       Gd       TA          ALQ          Unf        Ex
# 2          Gtl       Gd       TA          GLQ          Unf        Ex
# 3          Gtl       TA       Gd          ALQ          Unf        Gd
# 4          Gtl       Gd       TA          GLQ          Unf        Ex
# ...        ...      ...      ...          ...          ...       ...
# 1455       Gtl       Gd       TA          Unf          Unf        Ex
# 1456       Gtl       Gd       TA          ALQ          Rec        TA
# 1457       Gtl       TA       Gd          GLQ          Unf        Ex
# 1458       Gtl       TA       TA          GLQ          Rec        Gd
# 1459       Gtl       TA       TA          BLQ          LwQ        Gd
#
#      Electrical KitchenQual Functional FireplaceQu GarageQual GarageCond  \
# ...
